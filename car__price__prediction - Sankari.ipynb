# %% [markdown]
# SANKARI SREEKUMAR
#
# TASK 3 : CAR PRICE PREDICTION USING MACHINE LEARNING
#
# The price of a car depends on a lot of factors like the goodwill of the brand of the car,
# features of the car, horsepower and the mileage it gives and many more. Car price
# prediction is one of the major research areas in machine learning. We want to learn
# how to train a car price prediction model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/car data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
print("columns_count :", df.shape[1])
print("row_count:",df.shape[0])
print("names:","\n",df.columns)
# Out:
# columns_count : 9
# row_count: 301
# names:
#  Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(['Car_Name'],axis=1,inplace=True)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [299 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['current_year']=2024

# %%
df['Age_of_car']=df['current_year']-df['Year']

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  current_year  Age_of_car
# 0         Manual      0          2024          10
# 1         Manual      0          2024          11
# 2         Manual      0          2024           7
# 3         Manual      0          2024          13
# 4         Manual      0          2024          10
# ..           ...    ...           ...         ...
# 296       Manual      0          2024           8
# 297       Manual      0          2024           9
# 298       Manual      0          2024          15
# 299       Manual      0          2024           7
# 300       Manual      0          2024           8
#
# [299 rows x 10 columns]

# %%
df.drop(['current_year','Year'],axis=1,inplace=True)
df
# Out:
#      Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0             3.35           5.59       27000    Petrol       Dealer
# 1             4.75           9.54       43000    Diesel       Dealer
# 2             7.25           9.85        6900    Petrol       Dealer
# 3             2.85           4.15        5200    Petrol       Dealer
# 4             4.60           6.87       42450    Diesel       Dealer
# ..             ...            ...         ...       ...          ...
# 296           9.50          11.60       33988    Diesel       Dealer
# 297           4.00           5.90       60000    Petrol       Dealer
# 298           3.35          11.00       87934    Petrol       Dealer
# 299          11.50          12.50        9000    Diesel       Dealer
# 300           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  Age_of_car
# 0         Manual      0          10
# 1         Manual      0          11
# 2         Manual      0           7
# 3         Manual      0          13
# 4         Manual      0          10
# ..           ...    ...         ...
# 296       Manual      0           8
# 297       Manual      0           9
# 298       Manual      0          15
# 299       Manual      0           7
# 300       Manual      0           8
#
# [299 rows x 8 columns]

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age_of_car  \
# 0             3.35           5.59       27000      0          10
# 1             4.75           9.54       43000      0          11
# 2             7.25           9.85        6900      0           7
# 3             2.85           4.15        5200      0          13
# 4             4.60           6.87       42450      0          10
# ..             ...            ...         ...    ...         ...
# 296           9.50          11.60       33988      0           8
# 297           4.00           5.90       60000      0           9
# 298           3.35          11.00       87934      0          15
# 299          11.50          12.50        9000      0           7
# 300           5.30           5.90        5464      0           8
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0               False              True                    False
# 1                True             False                    False
# 2               False              True                    False
# 3               False              True                    False
# 4                True             False                    False
# ..                ...               ...                      ...
# 296              True             False                    False
# 297             False              True                    False
# 298             False              True                    False
# 299              True             False                    False
# 300             False              True                    False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [299 rows x 9 columns]

# %%
g=['Fuel_Type_Diesel','Fuel_Type_Petrol','Selling_type_Individual','Transmission_Manual']
df[g]=df[g].astype('int')

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age_of_car  \
# 0           3.35           5.59       27000      0          10
# 1           4.75           9.54       43000      0          11
# 2           7.25           9.85        6900      0           7
# 3           2.85           4.15        5200      0          13
# 4           4.60           6.87       42450      0          10
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                 0                 1                        0
# 1                 1                 0                        0
# 2                 0                 1                        0
# 3                 0                 1                        0
# 4                 1                 0                        0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
df.corr()
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.876305    0.028566 -0.087880
# Present_Price                 0.876305       1.000000    0.205224  0.009948
# Driven_kms                    0.028566       0.205224    1.000000  0.089367
# Owner                        -0.087880       0.009948    0.089367  1.000000
# Age_of_car                   -0.234369       0.053167    0.525714  0.181639
# Fuel_Type_Diesel              0.543541       0.464934    0.173295 -0.051836
# Fuel_Type_Petrol             -0.531636      -0.456829   -0.173595  0.054102
# Selling_type_Individual      -0.553851      -0.511779   -0.101030  0.123646
# Transmission_Manual          -0.348869      -0.334326   -0.163881 -0.052166
#
#                          Age_of_car  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price             -0.234369          0.543541         -0.531636
# Present_Price              0.053167          0.464934         -0.456829
# Driven_kms                 0.525714          0.173295         -0.173595
# Owner                      0.181639         -0.051836          0.054102
# Age_of_car                 1.000000         -0.056469          0.052197
# Fuel_Type_Diesel          -0.056469          1.000000         -0.979104
# Fuel_Type_Petrol           0.052197         -0.979104          1.000000
# Selling_type_Individual    0.036820         -0.345882          0.353865
# Transmission_Manual       -0.003434         -0.086264          0.078700
#
#                          Selling_type_Individual  Transmission_Manual
# Selling_Price                          -0.553851            -0.348869
# Present_Price                          -0.511779            -0.334326
# Driven_kms                             -0.101030            -0.163881
# Owner                                   0.123646            -0.052166
# Age_of_car                              0.036820            -0.003434
# Fuel_Type_Diesel                       -0.345882            -0.086264
# Fuel_Type_Petrol                        0.353865             0.078700
# Selling_type_Individual                 1.000000             0.058669
# Transmission_Manual                     0.058669             1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='Reds')
# Out:
# <Axes: >

# %%
y=df['Selling_Price']
x=df.drop(columns=['Selling_Price'])

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
x
# Out:
#      Present_Price  Driven_kms  Owner  Age_of_car  Fuel_Type_Diesel  \
# 0             5.59       27000      0          10                 0
# 1             9.54       43000      0          11                 1
# 2             9.85        6900      0           7                 0
# 3             4.15        5200      0          13                 0
# 4             6.87       42450      0          10                 1
# ..             ...         ...    ...         ...               ...
# 296          11.60       33988      0           8                 1
# 297           5.90       60000      0           9                 0
# 298          11.00       87934      0          15                 0
# 299          12.50        9000      0           7                 1
# 300           5.90        5464      0           8                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# 1                   0                        0                    1
# 2                   1                        0                    1
# 3                   1                        0                    1
# 4                   0                        0                    1
# ..                ...                      ...                  ...
# 296                 0                        0                    1
# 297                 1                        0                    1
# 298                 1                        0                    1
# 299                 0                        0                    1
# 300                 1                        0                    1
#
# [299 rows x 8 columns]

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [4.41984172e-01 3.96861818e-02 2.81262096e-04 8.41396182e-02
#  8.80778661e-02 2.19353472e-02 2.31965027e-01 9.19305252e-02]

# %%
feat_imp=pd.Series(model.feature_importances_,index=x.columns)
feat_imp.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (239, 8)

# %%
x_test.shape
# Out:
# (60, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict=regressor.predict(x_test)

# %%
y_predict
# Out:
# array([ 0.2095,  7.231 ,  2.5415,  1.506 ,  4.4181, 16.176 ,  4.2365,
#         0.5389, 14.8893,  1.188 ,  2.923 ,  0.2165, 21.4722,  2.995 ,
#         1.8825,  2.514 ,  4.7495, 19.9519,  7.5363,  7.1959,  6.7045,
#         1.2302, 10.647 ,  4.1502,  0.6242,  4.9585,  3.2645, 20.0055,
#        11.9438,  0.2767,  6.9672,  1.0641,  2.865 ,  2.52  ,  4.1065,
#         4.695 ,  4.4226,  0.2069,  4.8365,  0.4605,  5.7645,  6.5136,
#        15.0087,  3.6565,  5.3236,  1.0685,  1.5395,  5.7966,  5.147 ,
#         9.547 ,  4.4895, 14.7066,  6.287 ,  7.5383,  0.8241,  1.1841,
#         2.789 ,  7.0906,  2.499 ,  0.5894])

# %%
x_train.head(1)
# Out:
#      Present_Price  Driven_kms  Owner  Age_of_car  Fuel_Type_Diesel  \
# 239           4.43       23709      0          12                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 239                 1                        0                    1

# %%
input_data_model=pd.DataFrame(
   [[4.43	, 23709,	0,	12,	0,	1,	0,	1]],
   columns=['Present_Price',	'Driven_kms',	'Owner',	'Age_of_car',	'Fuel_Type_Diesel',	'Fuel_Type_Petrol',	'Selling_type_Individual',	'Transmission_Manual'])

# %%
input_data_model
# Out:
#    Present_Price  Driven_kms  Owner  Age_of_car  Fuel_Type_Diesel  \
# 0           4.43       23709      0          12                 0
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                 1                        0                    1

# %%
regressor.predict(input_data_model)
# Out:
# array([2.313])
